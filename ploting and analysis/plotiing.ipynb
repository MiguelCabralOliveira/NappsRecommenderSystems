# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# Load the data
df = pd.read_csv(r"C:\Users\mike_\Documents\NappsRecommenderSystem\products_with_tfidf.csv")
df1  = pd.read_csv(r"C:\Users\mike_\Documents\NappsRecommenderSystem\products.csv")

# %%
print("All columns in the DataFrame:")
for i, column in enumerate(df.columns, 1):
    print(f"{i}. {column}")
# Out:
# All columns in the DataFrame:
# 1. product_title
# 2. product_id
# 3. description
# 4. handle
# 5. product_type
# 6. rating
# 7. collection_ACESSÓRIOS
# 8. collection_ACTIVEWEAR & PADEL COLLECTION
# 9. collection_All
# 10. collection_BIQUÍNIS
# 11. collection_BONÉS E CHAPÉUS
# 12. collection_EASYWEAR
# 13. collection_FW’24/25 BOTTOMS
# 14. collection_FW’24/25 TOPS
# 15. collection_FW’24/25 TRACKSUIT COLLECTION
# 16. collection_KIDS
# 17. collection_LENÇOS
# 18. collection_LINGERIE
# 19. collection_LOUNGEWEAR
# 20. collection_OS MAIS VENDIDOS
# 21. collection_OUTLET
# 22. collection_PARÉOS
# 23. collection_SCRUNCHIES
# 24. collection_SLEEPWEAR
# 25. collection_SS'24 RJ COLLECTION 🇧🇷
# 26. collection_Smart Products Filter Index - Do not delete
# 27. collection_TRACKSUITS | LIMITED EDITION!
# 28. collection_TRIQUÍNIS & FATOS DE BANHO
# 29. tag_hoodie_conj
# 30. tag_satin_shirt
# 31. tag_satin_trousers
# 32. tag_sweatpants_conj
# 33. tag_sweatshirt_conj
# 34. related_products_count
# ...

# %%
df.head()
# Out:
#                           product_title                           product_id  \
# 0     SILK SCARF SS'24 RJ COLLECTION S5  gid://shopify/Product/9181456105813
# 1     SILK SCARF SS'24 RJ COLLECTION S6  gid://shopify/Product/9181456367957
# 2    SILK SCARF SS'24 RJ COLLECTION S12  gid://shopify/Product/9415774929237
# 3  SILK SCARF SS'23 PHILI COLLECTION S9  gid://shopify/Product/8653572604245
# 4      SILK SCARF SS22 ZANZI COLLECTION  gid://shopify/Product/7830973939939
#
#         vendor                                        description  \
# 0  missusstore  Data de Promoção: de 24 de Fevereiro a 31 de M...
# 1  missusstore  Data de Promoção: de 24 de Fevereiro a 31 de M...
# 2  missusstore  Data de Promoção: de 24 de Fevereiro a 31 de M...
# 3  missusstore  Data de Promoção: de 24 de Fevereiro a 31 de M...
# 4  missusstore  Data de Promoção: de 24 de Fevereiro a 31 de M...
#
#                               handle product_type related_products  rating  \
# ...

# %%
print("First product's data:")
for column in df.columns:
    print(f"\n{column}:")
    print(df.iloc[55][column])
# Out:
# First product's data:
#
# product_title:
# PANAMÁ MISSUS S6
#
# product_id:
# gid://shopify/Product/9508305895765
#
# description:
# Panamá laranja com logo Missus bordado a branco na frente. Tiras ajustáveis no interior. Tamanho único.
#
# handle:
# panama-missus-s6
#
# product_type:
# bone
#
# rating:
# nan
#
# collection_ACESSÓRIOS:
# 1
#
# collection_ACTIVEWEAR & PADEL COLLECTION:
# 0
#
# collection_All:
# 0
#
# collection_BIQUÍNIS:
# 0
#
# collection_BONÉS E CHAPÉUS:
# 0
#
# collection_EASYWEAR:
# 0
#
# collection_FW’24/25 BOTTOMS:
# 0
#
# collection_FW’24/25 TOPS:
# 0
#
# collection_FW’24/25 TRACKSUIT COLLECTION:
# 0
#
# collection_KIDS:
# 0
#
# collection_LENÇOS:
# 0
#
# collection_LINGERIE:
# 0
#
# collection_LOUNGEWEAR:
# 0
#
# collection_OS MAIS VENDIDOS:
# 0
#
# collection_OUTLET:
# 0
#
# collection_PARÉOS:
# 0
#
# collection_SCRUNCHIES:
# 0
#
# collection_SLEEPWEAR:
# 0
#
# collection_SS'24 RJ COLLECTION 🇧🇷:
# 0
#
# collection_Smart Products Filter Index - Do not delete:
# ...

# %%
print("First product's data:")
for column in df.columns:
    print(f"\n{column}:")
    print(df1.iloc[55][column])
# Out:
# First product's data:
#
# product_title:
# PANAMÁ MISSUS S6
#
# product_id:
# gid://shopify/Product/9508305895765
#
# description:
# Panamá laranja com logo Missus bordado a branco na frente. Tiras ajustáveis no interior. Tamanho único.
#
# handle:
# panama-missus-s6
#
# product_type:
# bone
#
# rating:
# nan
#
# collection_ACESSÓRIOS:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\mike_\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...
